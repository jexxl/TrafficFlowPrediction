# %%
library('forecast')
library('ggplot2')

df <- read.csv('data/approach_6.csv')[2:3]
flow <- ts(df[,-1])

flow <- msts(flow,  seasonal.periods=c(12*24, 12*24*7))
# Out:
# Warning message:
# "package 'forecast' was built under R version 3.6.3"Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
mstl(flow) %>% autoplot()
# Out:
# plot without title
