# %%
# %config InlineBackend.figure_format = 'retina'

from utils.utils import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima_model import ARIMA
import time
import progressbar
import warnings

sns.set()
warnings.filterwarnings('ignore')

# %% [markdown]
# # $\hat{y}(t)=y(t-1)$

# %%
ts = get_flow_series_by_idx(0)
ts = ts.resample('15min').sum()

pd.DataFrame(calc_metrics(ts.iloc[-4*24*7:], ts.iloc[-4*24*7-1:-1]), index=[0])
# Out:
#          mae       rmse       mape
# 0  17.081845  24.128161  17.424039

# %% [markdown]
# # MA

# %%
ts = get_flow_series_by_idx(0)
ts = ts.resample('15min').sum()

df = pd.DataFrame(columns=['mae','rmse','mape'])
df.index.name = 'span'
for i in range(1,8):
    rts = ts.shift(1).rolling(i).mean().iloc[-4*24*7:]
    df.loc[i] = calc_metrics(ts.iloc[-4*24*7:], rts.iloc[-4*24*7:])
df
# Out:
#             mae       rmse       mape
# span
# 1     17.081845  24.128161  17.424039
# 2     17.562500  25.159107  17.767821
# 3     19.508433  27.691789  20.013908
# 4     21.931920  30.937826  22.762920
# 5     24.170238  33.941357  25.654864
# 6     26.426339  36.908995  28.784952
# 7     28.647534  39.769367  32.008930

# %% [markdown]
# # EMA

# %%
ts = get_flow_series_by_idx(0)
ts = ts.resample('15min').sum()

df = pd.DataFrame(columns=['mae','rmse','mape'])
df.index.name = 'span'
for i in range(1,8):
    rts = ts.shift(1).ewm(span=i).mean().iloc[-4*24*7:]
    df.loc[i] = calc_metrics(ts.iloc[-4*24*7:], rts.iloc[-4*24*7:])
df
# Out:
#             mae       rmse       mape
# span
# 1     17.081845  24.128161  17.424039
# 2     17.334736  24.526511  17.668926
# 3     18.955810  26.581132  19.754986
# 4     20.816813  28.967135  22.426294
# 5     22.762153  31.403919  25.462912
# 6     24.782666  33.816041  28.794076
# 7     26.792433  36.181848  32.344804

# %% [markdown]
# # ARIMA without stl

# %%
from statsmodels.tsa.stattools import adfuller as ADF
def diff(timeseries):
    timeseries_diff1 = timeseries.diff(1)
    timeseries_diff2 = timeseries_diff1.diff(1)

    timeseries_diff1 = timeseries_diff1.fillna(0)
    timeseries_diff2 = timeseries_diff2.fillna(0)

    timeseries_adf = ADF(timeseries.tolist())
    timeseries_diff1_adf = ADF(timeseries_diff1.tolist())
    timeseries_diff2_adf = ADF(timeseries_diff2.tolist())

    print('timeseries_adf : ', timeseries_adf)
    print('timeseries_diff1_adf : ', timeseries_diff1_adf)
    print('timeseries_diff2_adf : ', timeseries_diff2_adf)

ts = get_flow_series_by_idx(0)
ts = ts.resample('15min').sum()
test_size = 4*24*7
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

diff(train_ts)  # ADF检验证明不需要差分
# Out:
# timeseries_adf :  (-11.326488741171374, 1.1401311078477662e-20, 27, 2180, {'1%': -3.4333532186762805, '5%': -2.862866720471125, '10%': -2.5674762791431696}, 20231.43162080327)
# timeseries_diff1_adf :  (-9.076560197905124, 4.163983546469705e-15, 25, 2182, {'1%': -3.4333504627066542, '5%': -2.8628655035890977, '10%': -2.567475631233297}, 20353.737141105237)
# timeseries_diff2_adf :  (-14.349745102277296, 1.0265146001881539e-26, 27, 2180, {'1%': -3.4333532186762805, '5%': -2.862866720471125, '10%': -2.5674762791431696}, 20429.070180154285)

# %%
# org
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
plt.figure(figsize=(15,5))
plt.subplot(121)
plot_acf(train_ts, ax=plt.gca())
plt.subplot(122)
plot_pacf(train_ts, ax=plt.gca())
plt.show()  # ACF没有迅速截尾

# %%
# diff 1
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
plt.figure(figsize=(15,5))
plt.subplot(121)
plot_acf(train_ts.diff(1).dropna(), ax=plt.gca())
plt.subplot(122)
plot_pacf(train_ts.diff(1).dropna(), ax=plt.gca())
plt.show()  # ACF与PACF都很快截尾

# %% [markdown]
# ## org

# %%
# 自动化调参
model = auto_arima(train_ts, trace=True)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=20523.786, BIC=20557.985, Time=1.844 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=26285.465, BIC=26296.865, Time=0.031 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=20768.808, BIC=20785.908, Time=0.144 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=24133.646, BIC=24150.745, Time=0.283 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=28972.412, BIC=28978.112, Time=0.017 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=20701.825, BIC=20730.324, Time=0.776 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=20707.717, BIC=20736.217, Time=0.413 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=20663.151, BIC=20703.050, Time=1.900 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=20633.574, BIC=20673.472, Time=1.399 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=20708.433, BIC=20731.233, Time=0.478 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=20652.646, BIC=20686.845, Time=0.970 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=20695.748, BIC=20729.947, Time=1.117 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=20524.248, BIC=20569.847, Time=2.607 seconds
# Total fit time: 11.985 seconds

# %%
model
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(2, 0, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=False, trend=None,
#       with_intercept=True)

# %%
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

history_lst = train_ts.tolist()
test_lst = test_ts.tolist()
y_pred = []

order = (2,0,2)
model = ARIMA(history_lst, order=order).fit()
y_pred.append(model.forecast()[0][0])

p = progressbar.ProgressBar()
for i in p(range(test_size-1)):
    history_lst.append(test_lst[i])
    model = ARIMA(history_lst, order=order).fit()
    y_pred.append(model.forecast()[0][0])

y_true = np.array(test_lst)
y_pred = np.array(y_pred)
# Out:
# arima order: (2, 0, 2)
# 100% (671 of 671) |######################| Elapsed Time: 0:10:46 Time:  0:10:46

# %%
# %matplotlib inline
test_y_pred(y_true, y_pred, plot_with_figsize=(15,3))
plt.xlim([500,600])  # 存在严重的平移现象
# Out:
# (500, 600)

# %%
pd.DataFrame(calc_metrics(y_true, y_pred), index=[0])
# Out:
#          mae       rmse       mape
# 0  15.906185  22.634856  17.301036

# %% [markdown]
# ## diff

# %% [markdown]
# 为了解决平移问题，采取差分的方法

# %%
# 自动化调参
model = auto_arima(train_ts, trace=True, d=1)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=20684.262, BIC=20718.458, Time=1.073 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=20802.003, BIC=20813.402, Time=0.032 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=20725.328, BIC=20742.426, Time=0.191 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=20726.031, BIC=20743.129, Time=0.219 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=20800.006, BIC=20805.706, Time=0.023 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=20690.291, BIC=20718.788, Time=0.716 seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=20711.899, BIC=20740.396, Time=0.636 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=20671.718, BIC=20711.614, Time=0.621 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=20670.571, BIC=20704.768, Time=0.838 seconds
# Fit ARIMA: (3, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=20678.655, BIC=20707.152, Time=0.389 seconds
# Fit ARIMA: (4, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=20671.800, BIC=20711.696, Time=1.477 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=20723.468, BIC=20746.266, Time=0.299 seconds
# Fit ARIMA: (4, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=20675.281, BIC=20709.477, Time=0.591 seconds
# Fit ARIMA: (4, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=20673.703, BIC=20719.298, Time=2.102 seconds
# Total fit time: 9.214 seconds

# %%
model
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(3, 1, 1), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=False, trend=None,
#       with_intercept=True)

# %%
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

history_lst = train_ts.tolist()
test_lst = test_ts.tolist()
y_pred = []

order = (3,1,1)
model = ARIMA(history_lst, order=order).fit()
y_pred.append(model.forecast()[0][0])

p = progressbar.ProgressBar()
for i in p(range(test_size-1)):
    history_lst.append(test_lst[i])
    model = ARIMA(history_lst, order=order).fit()
    y_pred.append(model.forecast()[0][0])

y_true = np.array(test_lst)
y_pred = np.array(y_pred)
# Out:
# 100% (671 of 671) |######################| Elapsed Time: 0:03:31 Time:  0:03:31

# %%
# %matplotlib inline
test_y_pred(y_true, y_pred, plot_with_figsize=(15,3))
plt.xlim([500,600])  # 平移现象依旧存在
# Out:
# (500, 600)

# %%
pd.DataFrame(calc_metrics(y_true, y_pred), index=[0])
# Out:
#         mae       rmse       mape
# 0  16.41779  23.578701  16.414925
