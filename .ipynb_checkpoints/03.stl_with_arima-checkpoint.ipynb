# %%
# %config InlineBackend.figure_format = 'retina'

from utils.utils import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller as ADF
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
import time
import progressbar
import warnings

sns.set()
warnings.filterwarnings('ignore')

# %% [markdown]
# # stl

# %%
ts = get_flow_series_by_idx(0)
ts = ts.resample('15min').sum()

test_size = 4*24*7
train_ts = ts[:-test_size]
test_ts = ts[-test_size:]

decomposition = seasonal_decompose(train_ts, period=4*24, two_sided=False)  # 末尾不缺失

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
trend.plot(figsize=(15,3))

# %%
seasonal.plot(figsize=(15,3))

# %%
residual.plot(figsize=(15,3))

# %% [markdown]
# # stationary

# %% [markdown]
# 目测trend不够平稳，需要差分，而residual比较平稳

# %% [markdown]
# ## ADF

# %%
def diff(timeseries):
    timeseries_diff1 = timeseries.diff(1)
    timeseries_diff2 = timeseries_diff1.diff(1)

    timeseries_diff1 = timeseries_diff1.fillna(0)
    timeseries_diff2 = timeseries_diff2.fillna(0)

    timeseries_adf = ADF(timeseries.tolist())
    timeseries_diff1_adf = ADF(timeseries_diff1.tolist())
    timeseries_diff2_adf = ADF(timeseries_diff2.tolist())

    print('timeseries_adf : ', timeseries_adf)
    print('timeseries_diff1_adf : ', timeseries_diff1_adf)
    print('timeseries_diff2_adf : ', timeseries_diff2_adf)

ts = get_flow_series_by_idx(0)
ts = ts.resample('15min').sum()
test_size = 4*24*7
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

diff(trend.dropna())  # 需要一阶差分
# Out:
# timeseries_adf :  (-1.6325675965966577, 0.4661470183446057, 26, 2085, {'1%': -3.4334902249934984, '5%': -2.862927213384133, '10%': -2.5675084878859504}, -2730.2199892643357)
# timeseries_diff1_adf :  (-11.708863843136726, 1.505773029638787e-21, 25, 2086, {'1%': -3.433488717753819, '5%': -2.862926547902014, '10%': -2.5675081335553003}, -2729.5201811143424)
# timeseries_diff2_adf :  (-13.766397620153384, 9.866291394037771e-26, 23, 2088, {'1%': -3.433485707610957, '5%': -2.8629252188514385, '10%': -2.5675074259130812}, -2600.2619862363363)

# %%
diff(residual.dropna())  # 不需要差分
# Out:
# timeseries_adf :  (-11.62544367190115, 2.3296987360742963e-21, 23, 2088, {'1%': -3.433485707610957, '5%': -2.8629252188514385, '10%': -2.5675074259130812}, 17769.563948244933)
# timeseries_diff1_adf :  (-13.965500282136828, 4.440685772533435e-26, 24, 2087, {'1%': -3.4334872119603324, '5%': -2.862925883058088, '10%': -2.567507779564507}, 17894.739156910928)
# timeseries_diff2_adf :  (-17.411510736809976, 4.882845076066018e-30, 25, 2086, {'1%': -3.433488717753819, '5%': -2.862926547902014, '10%': -2.5675081335553003}, 18068.26025733319)

# %% [markdown]
# ## trend

# %%
# org trend
plt.figure(figsize=(15,5))
plt.subplot(121)
plot_acf(trend.dropna(), ax=plt.gca())
plt.subplot(122)
plot_pacf(trend.dropna(), ax=plt.gca())
plt.show()

# %%
# diff trend
plt.figure(figsize=(15,5))
plt.subplot(121)
plot_acf(trend.diff(1).dropna(), ax=plt.gca())
plt.subplot(122)
plot_pacf(trend.diff(1).dropna(), ax=plt.gca())
plt.show()

# %% [markdown]
# ## residual

# %%
# org residual
plt.figure(figsize=(15,5))
plt.subplot(121)
plot_acf(residual.dropna(), ax=plt.gca())
plt.subplot(122)
plot_pacf(residual.dropna(), ax=plt.gca())
plt.show()

# %% [markdown]
# # model

# %% [markdown]
# ## trend

# %%
# trend
auto_arima(trend.dropna(), d=1)
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(2, 1, 3), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=False, trend=None,
#       with_intercept=True)

# %%
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

history_lst = train_ts.tolist()
test_lst = test_ts.tolist()
trend_pred = []

order = (2,1,3)

trend_arr = seasonal_decompose(history_lst, period=4*24, two_sided=False).trend
trend_arr = trend_arr[np.isfinite(trend_arr)]
model = ARIMA(trend_arr, order=order).fit()
trend_pred.append(model.forecast()[0][0])

p = progressbar.ProgressBar()
for i in p(range(test_size-1)):
    history_lst.append(test_lst[i])
    trend_arr = seasonal_decompose(history_lst, period=4*24, two_sided=False).trend
    trend_arr = trend_arr[np.isfinite(trend_arr)]
    model = ARIMA(trend_arr, order=order).fit()
    trend_pred.append(model.forecast()[0][0])

trend_pred = np.array(trend_pred)
# Out:
# 100% (671 of 671) |######################| Elapsed Time: 0:12:52 Time:  0:12:52

# %% [markdown]
# ## residual

# %%
# residual
auto_arima(residual.dropna(), d=0)
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(1, 0, 1), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=False, trend=None,
#       with_intercept=True)

# %%
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

history_lst = train_ts.tolist()
test_lst = test_ts.tolist()
residual_pred = []

order = (1,0,1)

residual_arr = seasonal_decompose(history_lst, period=4*24, two_sided=False).resid
residual_arr = residual_arr[np.isfinite(residual_arr)]
model = ARIMA(residual_arr, order=order).fit()
residual_pred.append(model.forecast()[0][0])

p = progressbar.ProgressBar()
for i in p(range(test_size-1)):
    history_lst.append(test_lst[i])
    residual_arr = seasonal_decompose(history_lst, period=4*24, two_sided=False).resid
    residual_arr = residual_arr[np.isfinite(residual_arr)]
    model = ARIMA(residual_arr, order=order).fit()
    residual_pred.append(model.forecast()[0][0])

residual_pred = np.array(residual_pred)
# Out:
# 100% (671 of 671) |######################| Elapsed Time: 0:02:24 Time:  0:02:24

# %% [markdown]
# ## seasonal

# %%
train_ts = ts.iloc[0:-test_size]
test_ts = ts.iloc[-test_size:]

history_lst = train_ts.tolist()
test_lst = test_ts.tolist()
seasonal_pred = []

seasonal_arr = seasonal_decompose(history_lst, period=4*24, two_sided=False).seasonal
seasonal_pred.append(seasonal_arr[-test_size])

p = progressbar.ProgressBar()
for i in p(range(test_size-1)):
    history_lst.append(test_lst[i])
    seasonal_arr = seasonal_decompose(history_lst, period=4*24, two_sided=False).seasonal
    seasonal_pred.append(seasonal_arr[-test_size])

seasonal_pred = np.array(seasonal_pred)
# Out:
# 100% (671 of 671) |######################| Elapsed Time: 0:00:01 Time:  0:00:01

# %% [markdown]
# ## sum

# %%
y_pred = trend_pred + seasonal_pred + residual_pred

# %%
y_true = test_ts.values

# %%
test_y_pred(y_true, y_pred, plot_with_figsize=(15,3))
plt.xlim([500,600])
# Out:
# (500, 600)

# %%
pd.DataFrame(calc_metrics(y_true, y_pred), index=[0])
# Out:
#          mae       rmse       mape
# 0  14.528594  20.290225  16.052948
